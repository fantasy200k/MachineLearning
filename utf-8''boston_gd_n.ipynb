# %%
print ("Om Vakaraduntaaya Namah")
# Out:
# Om Vakaraduntaaya Namah

# %%
import pandas as pd
import numpy as np

# %%
! ls /home/nbuser/
# Out:
# anaconda2_501  anaconda3_501  library  test_boston_gd.csv
# anaconda3_420  IfSharp	      R        train_boston_gd.csv

# %%
# /home/nbuser/result_boston_new.csv
# /home/nbuser/test_boston_gd.csv/home/nbuser/train_boston_gd.csv
# /home/nbuser/train_boston_gd.csv
train_data = pd.read_csv('/home/nbuser/train_boston_gd.csv',delimiter = ',')
test_data = pd.read_csv('/home/nbuser/test_boston_gd.csv',delimiter = ',')
train_data.isnull().sum()
# Out:
# # CRIM      0
#  ZN         0
#  INDUS      0
#  CHAS       0
#  NOX        0
#  RM         0
#  AGE        0
#  DIS        0
#  RAD        0
#  TAX        0
#  PTRATIO    0
#  B          0
#  LSTAT      0
#  Y          0
# dtype: int64

# %%
# y_train = train_data.iloc[:,13:14]
Y = train_data[' Y']
del train_data[' Y']

# %%
last = np.zeros(train_data.shape[0])
train_data['last'] = last
train_data.head(2)
# Out:
#      # CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# 0 -0.407850 -0.487722 -1.266023 -0.272599 -0.576134  1.239974  0.840122
# 1 -0.407374 -0.487722  0.247057 -0.272599 -1.016689  0.001946 -0.838337
#
#         DIS       RAD       TAX   PTRATIO         B     LSTAT  last
# 0 -0.520264 -0.752922 -1.278354 -0.303094  0.410571 -1.097990   0.0
# 1  0.336351 -0.523001 -0.060801  0.113032  0.291169 -0.520474   0.0

# %%
points = np.array(train_data)
points.shape
# Out:
# (379, 14)

# %%
len(points)
# Out:
# 379

# %%
train_data.shape[0]
# Out:
# 379

# %%
def step_gradient(points, learning_rate, m):
    m_slope = np.zeros(14)
    M = len(points)
    for i in range(M):
        x = points[i]   # no of rows 
        y = Y[i] 
        for j in range(14):
            m_slope[j] = m_slope[j]+(-2/M)* (y - (m * x).sum() )*x[j] # #Updating the weight and bias derivatives
  # update rule          
    for j in range(14):
        m[j] = m[j] - learning_rate*m_slope[j]
    
    return m

# %%
def gd(points, learning_rate, num_iterations):
    m=np.zeros(14)
    for i in range(num_iterations):
        m = step_gradient(points, learning_rate, m)
        print(i, " Cost: ", cost(points, m))
    return m

# %%
def cost(points, m):
    total_cost = 0
    M = len(points)
    for i in range(M):
        x = points[i]
        y = Y[i]
        total_cost += (1/M)*((y - (m*x).sum() )**2)     # cost = (1/N) * ∑(yi − y_train)2 {i from 1 to n}
    return total_cost

# %%
def run():
    learning_rate = 0.001  # defining the hyperparameters
    num_iterations = 1000  # defining the hyperparameters
    m = gd(points, learning_rate, num_iterations)
    print(m)
    return m

# %%
m=run()
# Out:
# 0  Cost:  598.3388966495456
# 1  Cost:  597.5709116510045
# 2  Cost:  596.8179538126806
# 3  Cost:  596.0796716160776
# 4  Cost:  595.3557221281584
# 5  Cost:  594.6457707896772
# 6  Cost:  593.9494912087463
# 7  Cost:  593.2665649594985
# 8  Cost:  592.5966813857185
# 9  Cost:  591.9395374093383
# 10  Cost:  591.29483734365
# 11  Cost:  590.6622927111356
# 12  Cost:  590.0416220658061
# 13  Cost:  589.4325508199164
# 14  Cost:  588.8348110749673
# 15  Cost:  588.2481414568826
# 16  Cost:  587.6722869552522
# 17  Cost:  587.1069987665547
# 18  Cost:  586.5520341412413
# 19  Cost:  586.0071562346066
# 20  Cost:  585.4721339613354
# 21  Cost:  584.9467418536489
# 22  Cost:  584.4307599229473
# 23  Cost:  583.9239735248764
# 24  Cost:  583.4261732277198
# 25  Cost:  582.9371546840516
# 26  Cost:  582.456718505542
# 27  Cost:  581.9846701408767
# 28  Cost:  581.5208197566722
# 29  Cost:  581.0649821213417
# 30  Cost:  580.6169764918301
# 31  Cost:  580.1766265031348
# ...

# %%
#  new coeff
m
# Out:
# array([-0.71780834,  0.55595632, -0.09389334,  1.417138  , -0.46624404,
#         3.98147951,  0.50962767, -0.55342928,  0.85458506,  0.07895533,
#        -1.49892369,  0.6743183 , -3.03189895,  0.        ])

# %%
m
# Out:
# array([-0.71780834,  0.55595632, -0.09389334,  1.417138  , -0.46624404,
#         3.98147951,  0.50962767, -0.55342928,  0.85458506,  0.07895533,
#        -1.49892369,  0.6743183 , -3.03189895,  0.        ])

# %%
test_data[1] = np.ones(test_data.shape[0])

# %%
y_test = []
x1=np.array(test_data)
M = x1.shape[0]
for i in range(M):
    x = x1[i]
    z=(m*x).sum()
    y_test.append(z)

# %%
add_row=test_data.columns
add_row
row=[]
for i in add_row:
    row.append(float(i))
row=np.array(row)
z=(row*m).sum()
z
# Out:
# -12.177819800543976

# %%
y_test.insert(0,z)

# %%
y_test=np.array(y_test)

# %%
y_test
# Out:
# array([-1.21778198e+01,  5.16130044e+00, -1.68629857e+00,  2.27519628e-02,
#        -2.71646485e+00, -1.82923011e+01,  4.23729812e+00, -8.57886463e-01,
#        -4.97526031e+00, -2.13701010e+00,  6.91472994e-01, -4.40762303e+00,
#        -2.61422123e+00, -1.06817684e+00,  2.38830328e+01,  2.87530398e-01,
#        -3.31068294e-01,  2.44387294e+00, -3.18490262e+00,  7.51072543e+00,
#         6.15291624e-02,  8.15835560e-02,  9.61373259e+00,  1.27903218e+01,
#         9.75744333e+00, -7.29384617e+00, -3.23923209e+00,  7.34391312e+00,
#         2.97737204e+00,  1.18856582e+01, -4.86040804e+00,  9.24633622e-01,
#         5.20169453e-01,  2.11886480e+00, -5.28375724e+00,  3.85001638e+00,
#         1.69429078e+00, -2.61922402e+00,  9.94190107e-01, -9.60478033e+00,
#        -1.76324758e+01,  4.08010204e+00,  5.86939766e+00, -9.65489622e-01,
#        -1.39143007e+00, -2.03906060e+01,  1.83402329e+01,  2.83017400e+00,
# ...

# %%
np.savetxt('/home/nbuser/result_boston_new.csv', y_test, delimiter=',',fmt='%1.5f')

# %%
! ls -ltr
# Out:
# total 0
# -rw-r--r-- 1 nbuser nbuser       0 May 24 08:37 README.md
# -rw-r--r-- 1 nbuser nbuser    3698 May 24 08:39 HousingData.csv
# -rw-r--r-- 1 nbuser nbuser     101 May 24 09:20 Ridge_coef (alpha=0.01).csv
# -rw-r--r-- 1 nbuser nbuser  287946 May 24 11:37 LinearRegStudentDemo(1) (2).ipynb
# -rw-r--r-- 1 nbuser nbuser  172225 May 31 10:52 pychurn.csv
# -rw-r--r-- 1 nbuser nbuser  103827 Jun  4 07:32 smote.png
# -rw-r--r-- 1 nbuser nbuser  726504 Jun  6 11:33 Handling Imbalanced Data.ipynb
# -rw-r--r-- 1 nbuser nbuser   12435 Jun 10 08:09 housing.csv
# -rw-r--r-- 1 nbuser nbuser  155868 Jun 13 10:28 boston_housing.ipynb
# -rw-r--r-- 1 nbuser nbuser 2013547 Jun 14 11:19 Churn Analysis working.ipynb
# -rw-r--r-- 1 nbuser nbuser 2102820 Jun 17 14:00 Churn Analysis Final fac.ipynb
# -rw-r--r-- 1 nbuser nbuser   13930 Jun 18 15:52 marketBasket.ipynb
# -rw-r--r-- 1 nbuser nbuser       0 Jun 19 17:20 result_boston_new.csv
# ...

# %%
! cat result_boston_new.csv
